# %% [markdown]
# # Importing neccesary modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('gas_prices.csv')

# %%
df
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# ...

# %% [markdown]
# This is the dataset of increment in Gas prices in diffrent contries

# %% [markdown]
# # Draw the simple line graph that shows the year and price increment in USA

# %%
plt.plot(df.Year,df.USA)

# %% [markdown]
# # Add Canada Prices in this Graph

# %%
plt.plot(df.Year,df.USA)
plt.plot(df.Year,df.Canada)
plt.show()

# %% [markdown]
# # Add  South korea And write the results

# %%
plt.plot(df.Year,df.USA)
plt.plot(df.Year,df.Canada)
plt.plot(df.Year,df['South Korea'])

plt.show()

# %% [markdown]
# RESULTS = The gas in South korea is much expensive then both the countries and value is still increasing Year By year

# %% [markdown]
# # Adding some styling to the Graph

# %%
from matplotlib import style # import style module
style.use("ggplot") # give ggplot parameter value to use() method


plt.figure(figsize=(8,5))
plt.plot(df.Year,df.USA, 'ro--', linewidth = 3,markersize = 10,label='USA')
plt.plot(df.Year,df.Canada,'go--', linewidth = 3,markersize = 10,label='Canada')
plt.plot(df.Year,df['South Korea'],'co--', linewidth = 3,markersize = 10,label='South Korea')
plt.title("GAS PRICES")
plt.xlabel("Years")
plt.ylabel("Prices Increase")
plt.legend()
plt.grid(color='k',linestyle='-.')
plt.show()

# %% [markdown]
# # On X -Axis we need Years with the gap of 3 Years
# #  Like 1990,1993,1996,.........

# %%
df.Year[::3]   # this we need in X axis
# Out:
# 0     1990
# 3     1993
# 6     1996
# 9     1999
# 12    2002
# 15    2005
# 18    2008
# Name: Year, dtype: int64

# %%
from matplotlib import style # import style module
style.use("ggplot") # give ggplot parameter value to use() method


plt.figure(figsize=(8,5))
plt.plot(df.Year,df.USA, 'ro--', linewidth = 3,markersize = 10,label='USA')
plt.plot(df.Year,df.Canada,'go--', linewidth = 3,markersize = 10,label='Canada')
plt.plot(df.Year,df['South Korea'],'co--', linewidth = 3,markersize = 10,label='South Korea')
plt.title("GAS PRICES")
plt.xlabel("Years")
plt.ylabel("Prices Increase")
plt.legend()
plt.grid(color='k',linestyle='-.')
plt.xticks(df.Year[::3])   # setting xticks
plt.show()

# %% [markdown]
# # Draw All the Countrys in One Graph

# %%
for country in df:    ### this giive us all the countrys 
    if country!='Year':
        print(country)
# Out:
# Australia
# Canada
# France
# Germany
# Italy
# Japan
# Mexico
# South Korea
# UK
# USA

# %%
for country in df:     
    if country!='Year':
        plt.plot(df.Year,df[country], label = country)
plt.legend()
plt.show()

# %% [markdown]
# # We need to put legend outside the graph

# %%
for country in df:     
    if country!='Year':
        plt.plot(df.Year,df[country], label = country)
plt.legend(bbox_to_anchor=(1.1, 1.05))
plt.show()

# %% [markdown]
# # Save the Graph

# %%
from matplotlib import style # import style module
style.use("ggplot") # give ggplot parameter value to use() method


plt.figure(figsize=(8,5))
plt.plot(df.Year,df.USA, 'ro--', linewidth = 3,markersize = 10,label='USA')
plt.plot(df.Year,df.Canada,'go--', linewidth = 3,markersize = 10,label='Canada')
plt.plot(df.Year,df['South Korea'],'co--', linewidth = 3,markersize = 10,label='South Korea')
plt.title("GAS PRICES")
plt.xlabel("Years")
plt.ylabel("Prices Increase")
plt.legend()
plt.grid(color='k',linestyle='-.')
plt.xticks(df.Year[::3])   # setting xticks
plt.savefig('mygraph.png', dpi=300)    # to save the graph in png format dpi is resolution 
plt.show()

# %% [markdown]
# #                      LOAD THE FIFA DATA SET

# %%
df=pd.read_csv('fifa_data.csv')

# %%
df
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %% [markdown]
# # Print overall skill level By Histogram

# %%
plt.hist(df.Overall)
plt.show()

# %% [markdown]
# # Setting up Bins

# %%
bins = [40,50,60,70,80,90,100]
plt.hist(df.Overall,bins=bins)
plt.show()

# %%
bins = [40,50,60,70,80,90,100]
plt.hist(df.Overall,bins=bins)
plt.xticks(bins)
plt.ylabel('Number of Players')
plt.xlabel('Skill Level')
plt.title('Distribution of Player Skills in FIFA 2018')

plt.savefig('histogram.png', dpi=300)

plt.show()

# %% [markdown]
# # Show with pie chart how many players play from left foot and right foot

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
df['Preferred Foot'].value_counts()  # we got the values of lest and right foot players
# Out:
# Right    13948
# Left      4211
# Name: Preferred Foot, dtype: int64

# %%
Right=13948
Left=4211
labels=['Right','Left']
plt.pie([Right,Left], labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x1f5f363c8d0>,
# ...
#  [Text(-0.8207744811065032, 0.7323450355975322, 'Right'),
#   Text(0.8207744468229571, -0.7323450740207577, 'Left')])

# %% [markdown]
# # Add Percentage to the Pie chart

# %%
Right=13948
Left=4211
labels=['Right','Left']
plt.title('Foot Preference of FIFA Players')
plt.pie([Right,Left], labels=labels,autopct='%.2f %%')  ## autopct command adds the percentage to the chart
plt.show()

# %% [markdown]
# # Show Playes By weight in Pie chart

# %%
plt.figure(figsize=(8,5), dpi=100)

plt.style.use('ggplot')

df.Weight = [int(x.strip('lbs')) if type(x)==str else x for x in df.Weight]

light = df.loc[df.Weight < 125].count()[0]
light_medium = df[(df.Weight >= 125) & (df.Weight < 150)].count()[0]
medium = df[(df.Weight >= 150) & (df.Weight < 175)].count()[0]
medium_heavy = df[(df.Weight >= 175) & (df.Weight < 200)].count()[0]
heavy = df[df.Weight >= 200].count()[0]

weights = [light,light_medium, medium, medium_heavy, heavy]
label = ['under 125', '125-150', '150-175', '175-200', 'over 200']
explode = (.4,.2,0,0,.4)

plt.title('Weight of Professional Soccer Players (lbs)')

plt.pie(weights, labels=label, explode=explode, pctdistance=0.8,autopct='%.2f %%')
plt.show()

# %% [markdown]
# # Compare the Teams with Box and Whiskers charts

# %%
plt.figure(figsize=(5,8), dpi=100)

plt.style.use('default')

barcelona = df.loc[df.Club == "FC Barcelona"]['Overall']
madrid = df.loc[df.Club == "Real Madrid"]['Overall']
revs = df.loc[df.Club == "New England Revolution"]['Overall']

#bp = plt.boxplot([barcelona, madrid, revs], labels=['a','b','c'], boxprops=dict(facecolor='red'))
bp = plt.boxplot([barcelona, madrid, revs], labels=['FC Barcelona','Real Madrid','NE Revolution'], patch_artist=True, medianprops={'linewidth': 2})

plt.title('Professional Soccer Team Comparison')
plt.ylabel('FIFA Overall Rating')

for box in bp['boxes']:
    # change outline color
    box.set(color='#4286f4', linewidth=2)
    # change fill color
    box.set(facecolor = '#e0e0e0' )
    # change hatch
    #box.set(hatch = '/')
    
plt.show()
